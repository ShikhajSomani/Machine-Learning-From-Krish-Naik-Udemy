# %% [markdown]
# # Diabetes Prediction

# %%
from sklearn.datasets import load_diabetes

# %%
dataset = load_diabetes()

# %%
dataset
# Out:
# {'data': array([[ 0.03807591,  0.05068012,  0.06169621, ..., -0.00259226,
#           0.01990749, -0.01764613],
#         [-0.00188202, -0.04464164, -0.05147406, ..., -0.03949338,
#          -0.06833155, -0.09220405],
#         [ 0.08529891,  0.05068012,  0.04445121, ..., -0.00259226,
#           0.00286131, -0.02593034],
#         ...,
#         [ 0.04170844,  0.05068012, -0.01590626, ..., -0.01107952,
#          -0.04688253,  0.01549073],
#         [-0.04547248, -0.04464164,  0.03906215, ...,  0.02655962,
#           0.04452873, -0.02593034],
#         [-0.04547248, -0.04464164, -0.0730303 , ..., -0.03949338,
#          -0.00422151,  0.00306441]]),
#  'target': array([151.,  75., 141., 206., 135.,  97., 138.,  63., 110., 310., 101.,
#          69., 179., 185., 118., 171., 166., 144.,  97., 168.,  68.,  49.,
#          68., 245., 184., 202., 137.,  85., 131., 283., 129.,  59., 341.,
#          87.,  65., 102., 265., 276., 252.,  90., 100.,  55.,  61.,  92.,
# ...

# %%
print(dataset['DESCR'])
# Out:
# .. _diabetes_dataset:
#
# Diabetes dataset
# ----------------
#
# Ten baseline variables, age, sex, body mass index, average blood
# pressure, and six blood serum measurements were obtained for each of n =
# 442 diabetes patients, as well as the response of interest, a
# quantitative measure of disease progression one year after baseline.
#
# **Data Set Characteristics:**
#
# :Number of Instances: 442
#
# :Number of Attributes: First 10 columns are numeric predictive values
#
# :Target: Column 11 is a quantitative measure of disease progression one year after baseline
#
# :Attribute Information:
#     - age     age in years
#     - sex
#     - bmi     body mass index
#     - bp      average blood pressure
#     - s1      tc, total serum cholesterol
#     - s2      ldl, low-density lipoproteins
#     - s3      hdl, high-density lipoproteins
#     - s4      tch, total cholesterol / HDL
#     - s5      ltg, possibly log of serum triglycerides level
# ...

# %%
import pandas as pd
df_diabetes = pd.DataFrame(dataset.data, columns=['age',
  'sex',
  'bmi',
  'bp',
  's1',
  's2',
  's3',
  's4',
  's5',
  's6'])
df_diabetes.head()
# Out:
#         age       sex       bmi  ...        s4        s5        s6
# 0  0.038076  0.050680  0.061696  ... -0.002592  0.019907 -0.017646
# 1 -0.001882 -0.044642 -0.051474  ... -0.039493 -0.068332 -0.092204
# 2  0.085299  0.050680  0.044451  ... -0.002592  0.002861 -0.025930
# 3 -0.089063 -0.044642 -0.011595  ...  0.034309  0.022688 -0.009362
# 4  0.005383 -0.044642 -0.036385  ... -0.002592 -0.031988 -0.046641
#
# [5 rows x 10 columns]

# %%
X = df_diabetes #Independent

# %%
y = dataset['target'] #Dependent

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3,random_state=10)

# %%
X_train.head()
# Out:
#           age       sex       bmi  ...        s4        s5        s6
# 249 -0.012780 -0.044642  0.060618  ...  0.034309  0.070207  0.007207
# 389 -0.005515  0.050680  0.001339  ... -0.039493 -0.041176 -0.088062
# 121  0.063504 -0.044642  0.017506  ...  0.034309  0.019907  0.011349
# 195  0.027178  0.050680  0.025051  ...  0.034309  0.007838  0.023775
# 69   0.016281 -0.044642 -0.046085  ... -0.039493 -0.051404  0.019633
#
# [5 rows x 10 columns]

# %%
X_train.corr()
# Out:
#           age       sex       bmi  ...        s4        s5        s6
# age  1.000000  0.197408  0.198359  ...  0.227110  0.314151  0.351570
# sex  0.197408  1.000000  0.108261  ...  0.324882  0.150956  0.193322
# bmi  0.198359  0.108261  1.000000  ...  0.412826  0.435505  0.358273
# bp   0.394903  0.221914  0.356324  ...  0.249141  0.420236  0.368882
# s1   0.238375  0.057674  0.226047  ...  0.559626  0.566312  0.356280
# s2   0.192920  0.180315  0.248146  ...  0.684840  0.325759  0.315890
# s3  -0.128403 -0.379464 -0.395021  ... -0.754616 -0.370523 -0.297055
# s4   0.227110  0.324882  0.412826  ...  1.000000  0.609983  0.436311
# s5   0.314151  0.150956  0.435505  ...  0.609983  1.000000  0.490970
# s6   0.351570  0.193322  0.358273  ...  0.436311  0.490970  1.000000
#
# [10 rows x 10 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt 
plt.figure(figsize=(15,15))
sns.heatmap(X_train.corr(), annot=True)
# Out:
# <Axes: >

# %%
from sklearn.tree import DecisionTreeRegressor
reg = DecisionTreeRegressor()
reg.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor()

# %% [markdown]
# # Hyperparameter Tuning

# %%
params = {
    'criterion':['squared_error', 'fried,man_mse', 'absolute_error', 'poisson'],
    'splitter':['best', 'random'],
    'max_depth':[1,2,3,4,5,10,15,20,25],
    'max_features':['auto','sqrt','log2']
}

# %%
from sklearn.model_selection import GridSearchCV

# %%
regressor = DecisionTreeRegressor()

# %%
grid = GridSearchCV(regressor, param_grid=params, cv=5, scoring='neg_mean_squared_error')

# %%
import warnings
warnings.filterwarnings('ignore')
grid.fit(X_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeRegressor(),
#              param_grid={'criterion': ['squared_error', 'fried,man_mse',
#                                        'absolute_error', 'poisson'],
#                          'max_depth': [1, 2, 3, 4, 5, 10, 15, 20, 25],
#                          'max_features': ['auto', 'sqrt', 'log2'],
#                          'splitter': ['best', 'random']},
#              scoring='neg_mean_squared_error')

# %%
grid.best_params_
# Out:
# {'criterion': 'poisson',
#  'max_depth': 3,
#  'max_features': 'sqrt',
#  'splitter': 'best'}

# %%
y_pred = grid.predict(X_test)

# %%
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

# %%
print(r2_score(y_test, y_pred))
print(mean_absolute_error(y_test, y_pred))
print(mean_squared_error(y_test, y_pred))
# Out:
# 0.37395099974075385
# 50.790349338661535
# 3961.4321630133677

# %%
model = DecisionTreeRegressor(criterion='poisson',max_depth=3, max_features='sqrt',splitter='best')

# %%
model.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor(criterion='poisson', max_depth=3, max_features='sqrt')

# %%
# Visualize the Decision Tree
from sklearn import tree
plt.figure(figsize=(15,10))
tree.plot_tree(model, filled=True)
# Out:
# [Text(0.5, 0.875, 'x[8] <= -0.004\npoisson = 18.919\nsamples = 309\nvalue = 152.738'),
#  Text(0.25, 0.625, 'x[2] <= 0.006\npoisson = 12.271\nsamples = 145\nvalue = 109.779'),
#  Text(0.375, 0.75, 'True  '),
#  Text(0.125, 0.375, 'x[2] <= -0.058\npoisson = 9.81\nsamples = 114\nvalue = 98.658'),
#  Text(0.0625, 0.125, 'poisson = 3.708\nsamples = 23\nvalue = 76.783'),
#  Text(0.1875, 0.125, 'poisson = 10.536\nsamples = 91\nvalue = 104.187'),
#  Text(0.375, 0.375, 'x[7] <= 0.062\npoisson = 12.36\nsamples = 31\nvalue = 150.677'),
#  Text(0.3125, 0.125, 'poisson = 11.821\nsamples = 30\nvalue = 153.4'),
#  Text(0.4375, 0.125, 'poisson = 0.0\nsamples = 1\nvalue = 69.0'),
#  Text(0.75, 0.625, 'x[2] <= 0.015\npoisson = 14.497\nsamples = 164\nvalue = 190.72'),
#  Text(0.625, 0.75, '  False'),
#  Text(0.625, 0.375, 'x[7] <= 0.031\npoisson = 12.543\nsamples = 85\nvalue = 159.365'),
#  Text(0.5625, 0.125, 'poisson = 12.65\nsamples = 37\nvalue = 131.865'),
# ...
